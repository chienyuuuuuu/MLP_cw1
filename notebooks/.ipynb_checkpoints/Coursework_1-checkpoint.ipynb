# %% [markdown]
# # Coursework 1
#
# This notebook is intended to be used as a starting point for your experiments. The instructions can be found in the instructions file located under spec/coursework1.pdf. The methods provided here are just helper functions. If you want more complex graphs such as side by side comparisons of different experiments you should learn more about matplotlib and implement them. Before each experiment remember to re-initialize neural network weights and reset the data providers so you get a properly initialized experiment. For each experiment try to keep most hyperparameters the same except the one under investigation so you can understand what the effects of each are.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

def train_model_and_plot_stats(
        model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True):
    
    # As well as monitoring the error over training also monitor classification
    # accuracy i.e. proportion of most-probable predicted classes being equal to targets
    data_monitors={'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}

    # Use the created objects to initialise a new Optimiser instance.
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors, notebook=notebook)

    # Run the optimiser for 5 epochs (full passes through the training set)
    # printing statistics every epoch.
    stats, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=stats_interval)

    # Plot the change in the validation and training set error over training.
    fig_1 = plt.figure(figsize=(8, 4))
    ax_1 = fig_1.add_subplot(111)
    for k in ['error(train)', 'error(valid)']:
        ax_1.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_1.legend(loc=0)
    ax_1.set_xlabel('Epoch number')
   
    # Plot the change in the validation and training set accuracy over training.
    fig_2 = plt.figure(figsize=(8, 4))
    ax_2 = fig_2.add_subplot(111)
    for k in ['acc(train)', 'acc(valid)']:
        ax_2.plot(np.arange(1, stats.shape[0]) * stats_interval, 
                  stats[1:, keys[k]], label=k)
    ax_2.legend(loc=0)
    ax_2.set_xlabel('Epoch number')
    
    return stats, keys, run_time, fig_1, ax_1, fig_2, ax_2

# %%
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.
import numpy as np
import tqdm
import logging
from mlp.data_providers import MNISTDataProvider

# Seed a random number generator
seed = 10102016 
rng = np.random.RandomState(seed)
batch_size = 50
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)

# %%
import numpy as np
def save_stats(fname, stats, runtime):
    np.savetxt(fname,stats,delimiter=',')
    fd = open(fname, 'a')
    fd.write(str(runtime))
    fd.close()

# %%
# The model set up code below is provided as a starting point.
# You will probably want to add further code cells for the
# different experiments you run.

from mlp.layers import AffineLayer, SoftmaxLayer, SigmoidLayer, ReluLayer, LeakyReluLayer, ELULayer, SELULayer
from mlp.errors import CrossEntropySoftmaxError
from mlp.models import MultipleLayerModel
from mlp.initialisers import ConstantInit, GlorotUniformInit, SELUInit, NormalInit, GlorotNormalInit
from mlp.learning_rules import GradientDescentLearningRule
from mlp.optimisers import Optimiser

#setup hyperparameters
learning_rate = 0.1
num_epochs = 100
stats_interval = 1
input_dim, output_dim, hidden_dim = 784, 10, 100

weights_init = GlorotUniformInit(rng=rng)
biases_init = ConstantInit(0.)


error = CrossEntropySoftmaxError()
# Use a basic gradient descent learning rule
learning_rule = GradientDescentLearningRule(learning_rate=learning_rate)

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
#Remember to use notebook=False when you write a script to be run in a terminal
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)

fig_1.savefig('ReLU_error.pdf')
fig_2.savefig('ReLU_accuracy.pdf')
save_stats("ReLU.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 4.7s to complete
#     error(train)=1.82e-01, acc(train)=9.46e-01, error(valid)=1.78e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 6.2s to complete
#     error(train)=1.16e-01, acc(train)=9.66e-01, error(valid)=1.22e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.9s to complete
#     error(train)=9.29e-02, acc(train)=9.72e-01, error(valid)=1.11e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.5s to complete
#     error(train)=8.39e-02, acc(train)=9.74e-01, error(valid)=1.08e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 3.8s to complete
#     error(train)=6.02e-02, acc(train)=9.82e-01, error(valid)=9.23e-02, acc(valid)=9.70e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 3.9s to complete
#     error(train)=4.39e-02, acc(train)=9.87e-01, error(valid)=8.67e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 5.4s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    LeakyReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('LeakyRelu_error.pdf')
fig_2.savefig('LeakyRelu_accuracy.pdf')
save_stats("LeakyRelu.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 6.9s to complete
#     error(train)=1.76e-01, acc(train)=9.48e-01, error(valid)=1.72e-01, acc(valid)=9.50e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 5.3s to complete
#     error(train)=1.29e-01, acc(train)=9.62e-01, error(valid)=1.33e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.7s to complete
#     error(train)=1.08e-01, acc(train)=9.67e-01, error(valid)=1.30e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.7s to complete
#     error(train)=7.37e-02, acc(train)=9.78e-01, error(valid)=1.07e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 7.4s to complete
#     error(train)=5.73e-02, acc(train)=9.84e-01, error(valid)=9.46e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 3.4s to complete
#     error(train)=6.56e-02, acc(train)=9.79e-01, error(valid)=1.08e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 4.6s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU_error.pdf')
fig_2.savefig('ELU_accuracy.pdf')
save_stats("ELU.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 5.2s to complete
#     error(train)=2.39e-01, acc(train)=9.29e-01, error(valid)=2.34e-01, acc(valid)=9.33e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 4.6s to complete
#     error(train)=1.45e-01, acc(train)=9.57e-01, error(valid)=1.49e-01, acc(valid)=9.57e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.7s to complete
#     error(train)=1.11e-01, acc(train)=9.66e-01, error(valid)=1.27e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.8s to complete
#     error(train)=9.21e-02, acc(train)=9.73e-01, error(valid)=1.09e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 5.0s to complete
#     error(train)=7.78e-02, acc(train)=9.77e-01, error(valid)=9.90e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 5.0s to complete
#     error(train)=6.28e-02, acc(train)=9.81e-01, error(valid)=8.99e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 5.2s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('SELU_error.pdf')
fig_2.savefig('SELU_accuracy.pdf')
save_stats("SELU.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 8.5s to complete
#     error(train)=2.59e-01, acc(train)=9.22e-01, error(valid)=2.49e-01, acc(valid)=9.26e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 10.7s to complete
#     error(train)=1.54e-01, acc(train)=9.55e-01, error(valid)=1.58e-01, acc(valid)=9.56e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.9s to complete
#     error(train)=1.10e-01, acc(train)=9.67e-01, error(valid)=1.24e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.8s to complete
#     error(train)=9.09e-02, acc(train)=9.72e-01, error(valid)=1.15e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 4.9s to complete
#     error(train)=8.06e-02, acc(train)=9.74e-01, error(valid)=1.08e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 7.0s to complete
#     error(train)=7.01e-02, acc(train)=9.78e-01, error(valid)=1.02e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 5.5s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SigmoidLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('Sigmoid_error.pdf')
fig_2.savefig('Sigmoid_accuracy.pdf')
save_stats("Sigmoid.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 5.6s to complete
#     error(train)=5.64e-01, acc(train)=8.47e-01, error(valid)=5.30e-01, acc(valid)=8.62e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 5.8s to complete
#     error(train)=3.74e-01, acc(train)=8.96e-01, error(valid)=3.48e-01, acc(valid)=9.06e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 4.3s to complete
#     error(train)=3.28e-01, acc(train)=9.05e-01, error(valid)=3.08e-01, acc(valid)=9.12e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.3s to complete
#     error(train)=2.86e-01, acc(train)=9.18e-01, error(valid)=2.67e-01, acc(valid)=9.22e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 4.3s to complete
#     error(train)=2.59e-01, acc(train)=9.25e-01, error(valid)=2.45e-01, acc(valid)=9.30e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 4.4s to complete
#     error(train)=2.34e-01, acc(train)=9.33e-01, error(valid)=2.22e-01, acc(valid)=9.36e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 4.3s to complete
# ...

# %%
import pandas as pd
ReLU = pd.read_csv("ReLU.csv")
LeakyRelu = pd.read_csv("LeakyRelu.csv")
ELU = pd.read_csv("ELU.csv")
SELU = pd.read_csv("SELU.csv")
Sigmoid = pd.read_csv("Sigmoid.csv")

fig_1 = plt.figure(figsize=(8, 4))
ReLU.iloc[0:100,2].plot(label='ReLU')
LeakyRelu.iloc[0:100,2].plot(label='LeakyRelu')
ELU.iloc[0:100,2].plot(label='ELU')
SELU.iloc[0:100,2].plot(label='SELU')
Sigmoid.iloc[0:100,2].plot(label='Sigmoid')
plt.title('Validation Error')
plt.xlabel('Epoch Number')
plt.legend()

fig_2 = plt.figure(figsize=(8, 4))
ReLU.iloc[0:100,3].plot(label='ReLU')
LeakyRelu.iloc[0:100,3].plot(label='LeakyRelu')
ELU.iloc[0:100,3].plot(label='ELU')
SELU.iloc[0:100,3].plot(label='SELU')
Sigmoid.iloc[0:100,3].plot(label='Sigmoid')
plt.title('Validation Accuracy')
plt.xlabel('Epoch Number')
plt.legend(loc='lower right')

fig_1.savefig('validation_error')
fig_2.savefig('validation_accuracy')

# %%
ReLU = pd.read_csv("ReLU.csv").iloc[0:100,3]
LeakyRelu = pd.read_csv("LeakyRelu.csv").iloc[0:100,3]
ELU = pd.read_csv("ELU.csv").iloc[0:100,3]
SELU = pd.read_csv("SELU.csv").iloc[0:100,3]
Sigmoid = pd.read_csv("Sigmoid.csv").iloc[0:100,3]

ReLU_e = pd.read_csv("ReLU.csv").iloc[0:100,2]
LeakyRelu_e = pd.read_csv("LeakyRelu.csv").iloc[0:100,2]
ELU_e = pd.read_csv("ELU.csv").iloc[0:100,2]
SELU_e = pd.read_csv("SELU.csv").iloc[0:100,2]
Sigmoid_e = pd.read_csv("Sigmoid.csv").iloc[0:100,2]

# def mean():
#     sum=0
#     for x in l:
#         sum += x
#     mean = sum/100
#     return mean

print(np.std(ReLU))
print(np.std(LeakyRelu))
print(np.std(ELU))
print(np.std(SELU))
print(np.std(Sigmoid))

print(np.mean(ReLU))
print(np.mean(LeakyRelu))
print(np.mean(ELU))
print(np.mean(SELU))
print(np.mean(Sigmoid))


x = np.arange(5)
mean = [np.mean(ReLU), np.mean(LeakyRelu), np.mean(ELU), np.mean(SELU), np.mean(Sigmoid)]
mean_e = [np.mean(ReLU_e), np.mean(LeakyRelu_e), np.mean(ELU_e), np.mean(SELU_e), np.mean(Sigmoid_e)]
std = [np.std(ReLU), np.std(LeakyRelu), np.std(ELU), np.std(SELU), np.std(Sigmoid)]
std_e = [np.std(ReLU_e), np.std(LeakyRelu_e), np.std(ELU_e), np.std(SELU_e), np.std(Sigmoid_e)]

fig = plt.figure(figsize=(10,6))

plt.subplot(121)
acc = plt.bar(x, mean, yerr = std)
acc[0].set_color('#FF5151')
acc[1].set_color('#FF9D6F')
acc[2].set_color('#00CACA')
acc[3].set_color('#46A3FF')
acc[4].set_color('#9393FF')
plt.legend(loc='upper right')
plt.xticks(x, ('ReLU', 'LeakyRelu', 'ELU', 'SELU', 'Sigmoid'))
plt.ylim(0.95,1)
plt.title('Validation Accuracy Mean')
plt.subplot(122)
err = plt.bar(x, mean_e, yerr = std_e)
err[0].set_color('#FF5151')
err[1].set_color('#FF9D6F')
err[2].set_color('#00CACA')
err[3].set_color('#46A3FF')
err[4].set_color('#9393FF')
plt.legend(loc='upper right')
plt.xticks(x, ('ReLU', 'LeakyRelu', 'ELU', 'SELU', 'Sigmoid'))
plt.ylim(0,0.2)
plt.title('Validation Error Mean')


plt.show()
fig.savefig('compare_mean.pdf')
# Out:
# 0.00378684816173
# 0.00392288159393
# 0.00528167577574
# 0.00622318656317
# 0.0174217451479
# 0.978391
# 0.97748
# 0.978401
# 0.977157
# 0.969614
# /afs/inf.ed.ac.uk/user/s17/s1771650/miniconda3/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__3_error.pdf')
fig_2.savefig('ELU_3_accuracy.pdf')
save_stats("ELU_3.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 6.9s to complete
#     error(train)=1.91e-01, acc(train)=9.43e-01, error(valid)=1.81e-01, acc(valid)=9.48e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 7.2s to complete
#     error(train)=1.18e-01, acc(train)=9.64e-01, error(valid)=1.22e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 6.7s to complete
#     error(train)=1.09e-01, acc(train)=9.66e-01, error(valid)=1.26e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 7.6s to complete
#     error(train)=7.34e-02, acc(train)=9.77e-01, error(valid)=1.01e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 7.8s to complete
#     error(train)=6.14e-02, acc(train)=9.81e-01, error(valid)=9.36e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 6.0s to complete
#     error(train)=5.86e-02, acc(train)=9.81e-01, error(valid)=9.96e-02, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 6.0s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__4_error.pdf')
fig_2.savefig('ELU_4_accuracy.pdf')
save_stats("ELU_4.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 8.2s to complete
#     error(train)=1.85e-01, acc(train)=9.42e-01, error(valid)=1.83e-01, acc(valid)=9.45e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 9.0s to complete
#     error(train)=1.22e-01, acc(train)=9.64e-01, error(valid)=1.36e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 7.0s to complete
#     error(train)=1.02e-01, acc(train)=9.67e-01, error(valid)=1.21e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 7.1s to complete
#     error(train)=7.28e-02, acc(train)=9.76e-01, error(valid)=1.02e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 7.1s to complete
#     error(train)=5.42e-02, acc(train)=9.83e-01, error(valid)=9.17e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 7.1s to complete
#     error(train)=5.15e-02, acc(train)=9.83e-01, error(valid)=9.12e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 7.2s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__5_error.pdf')
fig_2.savefig('ELU_5_accuracy.pdf')
save_stats("ELU_5.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 9.6s to complete
#     error(train)=1.69e-01, acc(train)=9.47e-01, error(valid)=1.71e-01, acc(valid)=9.48e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 9.6s to complete
#     error(train)=1.04e-01, acc(train)=9.67e-01, error(valid)=1.19e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 8.0s to complete
#     error(train)=8.80e-02, acc(train)=9.72e-01, error(valid)=1.08e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 10.6s to complete
#     error(train)=7.60e-02, acc(train)=9.75e-01, error(valid)=9.97e-02, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 8.0s to complete
#     error(train)=6.58e-02, acc(train)=9.79e-01, error(valid)=9.69e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 8.0s to complete
#     error(train)=4.39e-02, acc(train)=9.86e-01, error(valid)=8.24e-02, acc(valid)=9.75e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 8.0s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__6_error.pdf')
fig_2.savefig('ELU_6_accuracy.pdf')
save_stats("ELU_6.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 9.8s to complete
#     error(train)=1.70e-01, acc(train)=9.47e-01, error(valid)=1.68e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 11.2s to complete
#     error(train)=9.77e-02, acc(train)=9.69e-01, error(valid)=1.12e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 6.5s to complete
#     error(train)=8.11e-02, acc(train)=9.73e-01, error(valid)=1.05e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 6.5s to complete
#     error(train)=7.02e-02, acc(train)=9.77e-01, error(valid)=1.02e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 6.5s to complete
#     error(train)=5.55e-02, acc(train)=9.82e-01, error(valid)=1.00e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 6.5s to complete
#     error(train)=4.16e-02, acc(train)=9.86e-01, error(valid)=8.50e-02, acc(valid)=9.76e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 6.4s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__7_error.pdf')
fig_2.savefig('ELU_7_accuracy.pdf')
save_stats("ELU_7.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 12.2s to complete
#     error(train)=2.14e-01, acc(train)=9.31e-01, error(valid)=2.08e-01, acc(valid)=9.35e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 9.9s to complete
#     error(train)=1.40e-01, acc(train)=9.55e-01, error(valid)=1.51e-01, acc(valid)=9.52e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 11.2s to complete
#     error(train)=8.19e-02, acc(train)=9.74e-01, error(valid)=1.08e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 10.1s to complete
#     error(train)=6.53e-02, acc(train)=9.79e-01, error(valid)=9.11e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 10.7s to complete
#     error(train)=5.72e-02, acc(train)=9.81e-01, error(valid)=9.81e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 10.4s to complete
#     error(train)=6.86e-02, acc(train)=9.77e-01, error(valid)=1.17e-01, acc(valid)=9.67e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 9.9s to complete
# ...

# %%
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU__8_error.pdf')
fig_2.savefig('ELU_8_accuracy.pdf')
save_stats("ELU_8.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 11.8s to complete
#     error(train)=1.72e-01, acc(train)=9.45e-01, error(valid)=1.67e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 11.4s to complete
#     error(train)=1.16e-01, acc(train)=9.63e-01, error(valid)=1.32e-01, acc(valid)=9.61e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 8.4s to complete
#     error(train)=1.05e-01, acc(train)=9.68e-01, error(valid)=1.25e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 8.5s to complete
#     error(train)=5.86e-02, acc(train)=9.82e-01, error(valid)=9.71e-02, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 10.2s to complete
#     error(train)=6.31e-02, acc(train)=9.79e-01, error(valid)=1.03e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 8.3s to complete
#     error(train)=5.15e-02, acc(train)=9.83e-01, error(valid)=9.54e-02, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 12.0s to complete
# ...

# %%
ELU = pd.read_csv("ELU.csv")
ELU_3 = pd.read_csv("ELU_3.csv")
ELU_4 = pd.read_csv("ELU_4.csv")
ELU_5 = pd.read_csv("ELU_5.csv")
ELU_6 = pd.read_csv("ELU_6.csv")
ELU_7 = pd.read_csv("ELU_7.csv")
ELU_8 = pd.read_csv("ELU_8.csv")

fig_1 = plt.figure(figsize=(8, 4))
ELU.iloc[:,2].plot(label='ELU_2layers')
ELU_3.iloc[:,2].plot(label='ELU_3layers')
ELU_4.iloc[:,2].plot(label='ELU_4layers')
ELU_5.iloc[:,2].plot(label='ELU_5layers')
ELU_6.iloc[:,2].plot(label='ELU_6layers')
ELU_7.iloc[:,2].plot(label='ELU_7layers')
ELU_8.iloc[:,2].plot(label='ELU_8layers')
plt.title('2-8 layers Validation Error')
plt.xlabel('Epoch Number')
plt.legend()

fig_2 = plt.figure(figsize=(8, 4))
ELU.iloc[:,3].plot(label='ELU_2layers')
ELU_3.iloc[:,3].plot(label='ELU_3layers')
ELU_4.iloc[:,3].plot(label='ELU_4layers')
ELU_5.iloc[:,3].plot(label='ELU_5layers')
ELU_6.iloc[:,3].plot(label='ELU_6layers')
ELU_7.iloc[:,3].plot(label='ELU_7layers')
ELU_8.iloc[:,3].plot(label='ELU_8layers')
plt.title('2-8 layers Validation Accuracy')
plt.xlabel('Epoch Number')
plt.legend()

fig_1.savefig('2-8layers_validation_error')
fig_2.savefig('2-8layers_validation_accuracy')

# %%
ELU = pd.read_csv("ELU.csv").iloc[0:100,3]
ELU_3= pd.read_csv("ELU_3.csv").iloc[0:100,3]
ELU_4 = pd.read_csv("ELU_4.csv").iloc[0:100,3]
ELU_5 = pd.read_csv("ELU_5.csv").iloc[0:100,3]
ELU_6 = pd.read_csv("ELU_6.csv").iloc[0:100,3]
ELU_7 = pd.read_csv("ELU_7.csv").iloc[0:100,3]
ELU_8 = pd.read_csv("ELU_8.csv").iloc[0:100,3]

ELUe = pd.read_csv("ELU.csv").iloc[0:100,2]
ELUe_3= pd.read_csv("ELU_3.csv").iloc[0:100,2]
ELUe_4 = pd.read_csv("ELU_4.csv").iloc[0:100,2]
ELUe_5 = pd.read_csv("ELU_5.csv").iloc[0:100,2]
ELUe_6 = pd.read_csv("ELU_6.csv").iloc[0:100,2]
ELUe_7 = pd.read_csv("ELU_7.csv").iloc[0:100,2]
ELUe_8 = pd.read_csv("ELU_8.csv").iloc[0:100,2]


x = np.arange(7)
mean = [np.mean(ELU), np.mean(ELU_3), np.mean(ELU_4), np.mean(ELU_5), np.mean(ELU_6), np.mean(ELU_7), np.mean(ELU_8)]
#mean_e = [np.mean(ELUe), np.mean(ELUe_3), np.mean(ELUe_4), np.mean(ELUe_5), np.mean(ELUe_6), np.mean(ELUe_7), np.mean(ELUe_8)]

fig = plt.figure(figsize=(12,6))

plt.subplot(111)
acc = plt.bar(x, mean)
acc[0].set_color('#FF5151')
acc[1].set_color('#FF9D6F')
acc[2].set_color('#FFF0AC')
acc[3].set_color('#00CACA')
acc[4].set_color('#97CBFF')
acc[5].set_color('#46A3FF')
acc[6].set_color('#9393FF')
plt.ylim(0.97,0.99)
plt.legend(loc='upper left')
plt.xticks(x, ('ELU', 'ELU_3', 'ELU_4', 'ELU_5', 'ELU_6', 'ELU_7', 'ELU_8'))
plt.title('Validation Accuracy Mean')


plt.show()
fig.savefig('ELU_mean.pdf')
# Out:
# /afs/inf.ed.ac.uk/user/s17/s1771650/miniconda3/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
from mlp.initialisers import UniformInit
import math
#weights_init_in = UniformInit(-math.sqrt(3/input_dim),math.sqrt(3/input_dim),rng=rng)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, UniformInit(-math.sqrt(3/input_dim),math.sqrt(3/input_dim),rng=rng), biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2  = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU_FanIn_error.pdf')
fig_2.savefig('ELU_FanIn_accuracy.pdf')
save_stats("ELU_FanIn.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 8.8s to complete
#     error(train)=1.83e-01, acc(train)=9.43e-01, error(valid)=1.75e-01, acc(valid)=9.46e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 12.2s to complete
#     error(train)=1.25e-01, acc(train)=9.61e-01, error(valid)=1.40e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 12.0s to complete
#     error(train)=8.32e-02, acc(train)=9.74e-01, error(valid)=1.04e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 9.3s to complete
#     error(train)=7.59e-02, acc(train)=9.76e-01, error(valid)=1.07e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 6.9s to complete
#     error(train)=5.46e-02, acc(train)=9.83e-01, error(valid)=9.00e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 9.3s to complete
#     error(train)=5.58e-02, acc(train)=9.82e-01, error(valid)=1.01e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 6.8s to complete
# ...

# %%
#weights_init_out = UniformInit(-math.sqrt(3/output_dim),math.sqrt(3/output_dim),rng=rng)

model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, UniformInit(-math.sqrt(3/hidden_dim),math.sqrt(3/hidden_dim),rng=rng), biases_init),
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, UniformInit(-math.sqrt(3/output_dim),math.sqrt(3/output_dim),rng=rng), biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2  = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU_FanOut_error.pdf')
fig_2.savefig('ELU_FanOut_accuracy.pdf')
save_stats("ELU_FanOut.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 10.5s to complete
#     error(train)=1.48e-01, acc(train)=9.54e-01, error(valid)=1.53e-01, acc(valid)=9.54e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 9.2s to complete
#     error(train)=9.89e-02, acc(train)=9.69e-01, error(valid)=1.28e-01, acc(valid)=9.63e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 9.1s to complete
#     error(train)=8.00e-02, acc(train)=9.74e-01, error(valid)=1.14e-01, acc(valid)=9.68e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 10.0s to complete
#     error(train)=6.19e-02, acc(train)=9.80e-01, error(valid)=1.01e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 10.9s to complete
#     error(train)=5.00e-02, acc(train)=9.83e-01, error(valid)=1.02e-01, acc(valid)=9.71e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 17.4s to complete
#     error(train)=4.42e-02, acc(train)=9.85e-01, error(valid)=1.03e-01, acc(valid)=9.72e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 13.7s to complete
# ...

# %%
weights_init_in_out = UniformInit(-math.sqrt(6/(input_dim+output_dim)),math.sqrt(6/(input_dim+output_dim)),rng=rng)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init_in_out, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init_in_out, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init_in_out, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init_in_out, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init_in_out, biases_init), 
    ELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init_in_out, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2  = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('ELU_FanInOut_error.pdf')
fig_2.savefig('ELU_FanInOut_accuracy.pdf')
save_stats("ELU_FanInOut.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 6.6s to complete
#     error(train)=2.68e-01, acc(train)=9.21e-01, error(valid)=2.52e-01, acc(valid)=9.27e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 5.2s to complete
#     error(train)=1.90e-01, acc(train)=9.43e-01, error(valid)=1.82e-01, acc(valid)=9.47e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 6.5s to complete
#     error(train)=1.41e-01, acc(train)=9.58e-01, error(valid)=1.45e-01, acc(valid)=9.59e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 4.1s to complete
#     error(train)=1.14e-01, acc(train)=9.65e-01, error(valid)=1.23e-01, acc(valid)=9.64e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 3.7s to complete
#     error(train)=9.53e-02, acc(train)=9.71e-01, error(valid)=1.12e-01, acc(valid)=9.66e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 4.2s to complete
#     error(train)=7.88e-02, acc(train)=9.76e-01, error(valid)=9.98e-02, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 4.2s to complete
# ...

# %%
ELU = pd.read_csv("ELU_6.csv")
ELU_FanIn = pd.read_csv("ELU_FanIn.csv")
ELU_FanOut = pd.read_csv("ELU_FanOut.csv")
#ELU_FanInOut = pd.read_csv("ELU_FanInOut.csv")

fig_1 = plt.figure(figsize=(8, 4))
ELU.iloc[:,2].plot(label='GlorotUniform')
ELU_FanIn.iloc[:,2].plot(label='Fan-in')
ELU_FanOut.iloc[:,2].plot(label='Fan-out')
#ELU_FanInOut.iloc[:,2].plot(label='Fan-in and Fan-out')
plt.title('Different Weight Initialisation for Validation Error')
plt.xlabel('Epoch Number')
plt.legend()

fig_2 = plt.figure(figsize=(8, 4))
ELU.iloc[:,3].plot(label='GlorotUniform')
ELU_FanIn.iloc[:,3].plot(label='Fan-in')
ELU_FanOut.iloc[:,3].plot(label='Fan-out')
#ELU_FanInOut.iloc[:,3].plot(label='Fan-in and Fan-out')
plt.title('Different Weight Initialisation for Validation Accuracy')
plt.xlabel('Epoch Number')
plt.legend(loc='lower right')

fig_1.savefig('diff_initial_validation_error')
fig_2.savefig('diff_initial_validation_accuracy')

# %%
weights_SELU_N = NormalInit(0,1/output_dim,rng=rng)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_SELU_N, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_SELU_N, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_SELU_N, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2  = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('SELU_Normal_error.pdf')
fig_2.savefig('SELU_Normal_accuracy.pdf')
save_stats("SELU_Normal.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 2.5s to complete
#     error(train)=2.10e-01, acc(train)=9.40e-01, error(valid)=2.02e-01, acc(valid)=9.43e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 1.6s to complete
#     error(train)=1.35e-01, acc(train)=9.61e-01, error(valid)=1.44e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 2.0s to complete
#     error(train)=1.25e-01, acc(train)=9.62e-01, error(valid)=1.41e-01, acc(valid)=9.58e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 1.6s to complete
#     error(train)=9.32e-02, acc(train)=9.71e-01, error(valid)=1.18e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 1.8s to complete
#     error(train)=6.99e-02, acc(train)=9.79e-01, error(valid)=1.06e-01, acc(valid)=9.69e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 1.5s to complete
#     error(train)=5.99e-02, acc(train)=9.81e-01, error(valid)=9.79e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 1.8s to complete
# ...

# %%
weights_init = GlorotNormalInit(rng=rng)
model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init, biases_init), 
    SELULayer(),
    AffineLayer(hidden_dim, output_dim, weights_init, biases_init)
])
stats, keys, runtime, fig_1, ax_1, fig_2, ax_2 = train_model_and_plot_stats(
    model, error, learning_rule, train_data, valid_data, num_epochs, stats_interval, notebook=True)
fig_1.savefig('SELU_GN_error.pdf')
fig_2.savefig('SELU_GN_accuracy.pdf')
save_stats("SELU_GN.csv", stats, runtime)
# Out:
# ...
# Epoch 1: 5.8s to complete
#     error(train)=2.45e-01, acc(train)=9.27e-01, error(valid)=2.33e-01, acc(valid)=9.34e-01, params_penalty=0.00e+00
# ...
# Epoch 2: 6.8s to complete
#     error(train)=1.64e-01, acc(train)=9.50e-01, error(valid)=1.66e-01, acc(valid)=9.51e-01, params_penalty=0.00e+00
# ...
# Epoch 3: 5.3s to complete
#     error(train)=1.12e-01, acc(train)=9.67e-01, error(valid)=1.27e-01, acc(valid)=9.62e-01, params_penalty=0.00e+00
# ...
# Epoch 4: 5.2s to complete
#     error(train)=9.63e-02, acc(train)=9.71e-01, error(valid)=1.23e-01, acc(valid)=9.65e-01, params_penalty=0.00e+00
# ...
# Epoch 5: 5.8s to complete
#     error(train)=8.02e-02, acc(train)=9.76e-01, error(valid)=1.08e-01, acc(valid)=9.70e-01, params_penalty=0.00e+00
# ...
# Epoch 6: 6.6s to complete
#     error(train)=6.30e-02, acc(train)=9.81e-01, error(valid)=9.34e-02, acc(valid)=9.73e-01, params_penalty=0.00e+00
# ...
# Epoch 7: 5.3s to complete
# ...

# %%
SELU = pd.read_csv("SELU.csv")
SELU_GN = pd.read_csv("SELU_GN.csv")
SELU_Normal = pd.read_csv("SELU_Normal.csv")


fig_1 = plt.figure(figsize=(8, 4))
SELU.iloc[:,2].plot(label='GlorotUniformInit')
SELU_GN.iloc[:,2].plot(label='GlorotNormalInit')
SELU_Normal.iloc[:,2].plot(label='Gaussian with mean 0 and variance 1/nout')
plt.title('Validation Error')
plt.xlabel('Epoch Number')
plt.legend()

fig_2 = plt.figure(figsize=(8, 4))
SELU.iloc[:,3].plot(label='GlorotUniformInit')
SELU_GN.iloc[:,3].plot(label='GlorotNormalInit')
SELU_Normal.iloc[:,3].plot(label='Gaussian with mean 0 and variance 1/nout')
plt.title('Validation Accuracy')
plt.xlabel('Epoch Number')
plt.legend(loc='lower right')

fig_1.savefig('diff_distribution_validation_error')
fig_2.savefig('diff_distribution_validation_accuracy')

# %%
SELU = pd.read_csv("SELU.csv").iloc[0:100,3]
SELU_GN = pd.read_csv("SELU_GN.csv").iloc[0:100,3]
SELU_Normal = pd.read_csv("SELU_Normal.csv").iloc[0:100,3]

SELU = pd.read_csv("SELU.csv").iloc[0:100,2]
SELU_GN = pd.read_csv("SELU_GN.csv").iloc[0:100,2]
SELU_Normal = pd.read_csv("SELU_Normal.csv").iloc[0:100,2]


x = np.arange(3)
mean = [np.mean(SELU), np.mean(SELU_GN), np.mean(SELU_Normal)]
std = [np.std(SELU), np.std(SELU_GN), np.std(SELU_Normal)]
print(np.mean(SELU))
fig = plt.figure(figsize=(9,6))

plt.subplot(111)
acc = plt.bar(x, mean, yerr = std)
acc[0].set_color('#FF5151')
acc[1].set_color('#FF9D6F')
acc[2].set_color('#00CACA')
plt.legend(loc='upper right')
plt.xticks(x, ('GlorotUniformInit', 'GlorotNormalInit', 'Gaussian with mean 0 and variance 1/nout'))

plt.title('Validation Accuracy Mean')


plt.show()
fig.savefig('compare_mean_distribution.pdf')
# Out:
# 0.107753017376
# /afs/inf.ed.ac.uk/user/s17/s1771650/miniconda3/envs/mlp/lib/python3.6/site-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
